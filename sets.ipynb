# %% [markdown]
# <a href="https://colab.research.google.com/github/aagamaar/Python_Revisiting/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = {"Alex","John","Alice", "John","Derry"}
print(students)
# Out:
# {'Alex', 'Derry', 'John', 'Alice'}

# %%
students.add("David")
print(students)
# Out:
# {'Alice', 'Alex', 'Derry', 'John', 'David'}

# %%
students.remove("John")
print(students)
# Out:
# {'Alice', 'Alex', 'Derry', 'David'}

# %%
for student in students:
  print(student)
# Out:
# Alice
# Alex
# Derry
# David

# %%
my_list = [1,1,2,2,3,3,4,5]
print(my_list)
# Out:
# [1, 1, 2, 2, 3, 3, 4, 5]

# %%
my_list = set(my_list)
print(list(my_list))
# Out:
# [1, 2, 3, 4, 5]
