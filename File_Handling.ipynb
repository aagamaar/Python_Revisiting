# %% [markdown]
# <a href="https://colab.research.google.com/github/aagamaar/Python_Revisiting/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Opening and reading a file

# %%
#Open a file in read mode
file = open("notes.txt", "r")

# read the content
content = file.read()

#print what we record
print(content)

#close the file
file.close()
# Out:
# HEY
# girl
# cutiee

# %%
with open("notes.txt", "r") as file:
  content = file.read()
  print(content)
# Out:
# HEY
# girl
# cutiee

# %% [markdown]
# Writing to a file

# %%
with open("output.txt", "w") as file:
  file.write("How are you?")
  file.write("Girlieee")

# %%
with open("output.txt", "w") as file:
    file.write("This is my second file!\n")
    file.write("Java makes file handling easy.\n")

# %% [markdown]
# Appending to a file

# %%
with open("output.txt", "a") as file:
    file.write("This is my third file!\n")
    file.write("Java makes file handling easy.")

# %%
with open("output.txt", "r") as file:
    for line in file:
      print("line : ", line.strip())
# Out:
# line :  This is my second file!
# line :  Java makes file handling easy.
# line :  This is my third file!
# line :  Java makes file handling easy.

# %%
import os
if os.path.exists("notes.txt"):
  with open("notes.txt","r") as file:
    print(file.read())
else:
  print("file not found")
# Out:
# HEY
# girl
# cutiee

# %%
import os
if os.path.exists("note.txt"):
  with open("notes.txt","r") as file:
    print(file.read())
else:
  print("file not found")
# Out:
# file not found
