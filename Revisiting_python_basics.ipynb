# %% [markdown]
# <a href="https://colab.research.google.com/github/aagamaar/Python_Revisiting/blob/main/Revisiting_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Printing hello world

# %%
print("hello world!")
# Out:
# hello world!

# %%
# variables are used to store data
name = "Alice"
age = 25
height = 5.7
is_student = True

# Output the variables
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is a student:", is_student)
# Out:
# Name: Alice
# Age: 25
# Height: 5.7
# Is a student: True

# %% [markdown]
# Data Types

# %%
x = "Hello"
y = 10
z = 3.3
a = False

#type()
print(type(x))
print(type(y))
print(type(z))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Taking Input

# %%
name = input("What is your name?")
age = int(input("What is your age?"))

print("Hello", name+"!")
print("You are", age, "years old !")
# Out:
# What is your name?
# What is your age?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3939/3509129448.py in <cell line: 0>()
#       1 name = input("What is your name?")
# ----> 2 age = int(input("What is your age?"))
#       3
#       4 print("Hello", name+"!")
#       5 print("You are", age, "years old !")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# convert input to int and float
age = int(input("Enter your age: "))
height = float(input("Enter your height in feet: "))

print("Age:", age)
print("Height:", height)


print(type(age))
print(type(height))

# %% [markdown]
# Operators in Python

# %%
a = 10
b = 3

print(a + b) #13
print(a - b) #7
print(a * b) #30
print(a / b) #3.33333
print(a // b) #3
print(a % b) #1
print(a ** b) #1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# Comparison Operators

# %%
x = 5
y = 10

print(x == y) #False
print(x != y) #True
print(x > y) #False
print(x < y) #True
print(x <= y) #True
print(x >= y) #False
# Out:
# False
# True
# False
# True
# True
# False

# %% [markdown]
# Logical Operators

# %%
is_adult = True
has_id = False

print(is_adult and has_id) #False
print(is_adult or has_id) #True
print(not is_adult) #False
# Out:
# False
# True
# False

# %% [markdown]
# Basic if statement

# %%
age = int(input("Enter your age:"))
if (age>=18):
  print("You are an adult !")
# Out:
# Enter your age:21
# You are an adult !

# %% [markdown]
# if and else

# %%
age = int(input("Enter your age:"))
if (age>=18):
  print("You can vote !")
else:
  print("You cant vote !")
# Out:
# Enter your age:21
# You can vote !

# %% [markdown]
# if elif else
#
# elif --> else if

# %%
marks = int(input("Enter your score (out of 100): "))

if marks>=90:
  print("Grade: A")
elif marks>=75:
  print("Grade: B")
elif marks >= 60:
  print("Grade: C")
else:
  print("Grade: D or below - keep learning !")
# Out:
# Enter your score (out of 100): 85
# Grade: B

# %% [markdown]
# Nested if statements

# %%
age = int(input("Enter your age: "))
has_id = input("Do you have an ID? (yes/no): ")

if age >= 18:
    if has_id == "yes":
        print("Entry allowed.")
    else:
        print("You need to show ID.")
else:
    print("You're not allowed. Must be 18 or older.")
# Out:
# Enter your age: 21
# Do you have an ID? (yes/no): yes
# Entry allowed.

# %% [markdown]
# Combining conditions with and/ or

# %%
age = int(input("Enter your age: "))
has_ticket = input("Do you have a ticket? (yes/no): ")

if age >= 18 and has_ticket == "yes":
    print("Welcome to the concert!")
else:
    print("Sorry, you must be 18+ and have a ticket.")
# Out:
# Enter your age: 21
# Do you have a ticket? (yes/no): yes
# Welcome to the concert!
